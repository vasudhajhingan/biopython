# %%
from Bio.Seq import Seq
print("GATCGATGGGCCTATAT".count("GGG"))
# Out:
# 1

# %%
from Bio.Seq import Seq
my_seq = Seq("GATCGATGGGCCTATAT")
print(my_seq[::-1])
# Out:
# TATATCCGGGTAGCTAG

# %%
print(my_seq[3::6])
# Out:
# CGA

# %%
print(my_seq.translate())
# Out:
# DRWAY

# %%
print(((my_seq.count("A") + my_seq.count("T")) / len(my_seq)) *100)
# Out:
# 52.94117647058824

# %%
print(my_seq.transcribe())
# Out:
# GAUCGAUGGGCCUAUAU

# %%
print(my_seq.reverse_complement())
# Out:
# ATATAGGCCCATCGATC

# %%
from Bio.SeqIO import parse
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq

f = open("NC_005816.fna.txt")

records = parse(f, "fasta")
for record in records:
    print("ID: %s" % record.id)
    print("Sequence Data: %s" % record.seq)
    print("Name: %s" % record.name)
    print("Description: %s" % record.description)
# Out:
# ID: gi|45478711|ref|NC_005816.1|
# Sequence Data: ...
# Name: gi|45478711|ref|NC_005816.1|
# Description: gi|45478711|ref|NC_005816.1| Yersinia pestis biovar Microtus str. 91001 plasmid pPCP1, complete sequence

# %%
from Bio.Seq import MutableSeq
mutable_seq = MutableSeq("GATCGATGGGCCTATAT")
print(mutable_seq)
print(mutable_seq[4]=="A")
# Out:
# GATCGATGGGCCTATAT
# False

# %%
my_seq = Seq("GATCG")
for index, letter in enumerate(my_seq):
    print("%i %s" % (index, letter))
# Out:
# 0 G
# 1 A
# 2 T
# 3 C
# 4 G
